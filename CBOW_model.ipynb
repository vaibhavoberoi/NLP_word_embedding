# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\vaibhav\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\vaibhav\anaconda3\lib\site-packages (from gensim) (1.9.0)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\vaibhav\anaconda3\lib\site-packages (from gensim) (1.16.2)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\vaibhav\anaconda3\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in c:\users\vaibhav\anaconda3\lib\site-packages (from gensim) (1.12.0)
# Requirement already satisfied: requests in c:\users\vaibhav\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.21.0)
# Requirement already satisfied: boto3 in c:\users\vaibhav\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (1.10.39)
# Requirement already satisfied: boto>=2.32 in c:\users\vaibhav\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\vaibhav\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\vaibhav\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\vaibhav\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vaibhav\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.11.28)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in c:\users\vaibhav\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.2.1)
# Requirement already satisfied: botocore<1.14.0,>=1.13.39 in c:\users\vaibhav\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (1.13.39)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\vaibhav\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.4)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\users\vaibhav\anaconda3\lib\site-packages (from botocore<1.14.0,>=1.13.39->boto3->smart-open>=1.8.1->gensim) (0.14)
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in c:\users\vaibhav\anaconda3\lib\site-packages (from botocore<1.14.0,>=1.13.39->boto3->smart-open>=1.8.1->gensim) (2.8.0)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize


import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

from nltk.corpus import stopwords
import re

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

import gensim
from gensim.models import Word2Vec


import glob

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    warnings.warn("deprecated", DeprecationWarning)

# %%
df=pd.read_csv(r'C:\Users\Vaibhav\Documents\Practicum\dataminingassignment\Outputair-canada.csv')
data=[]
data=' '.join(df['Comment'].loc[i] for i in range(df.shape[0]))

# %%
data=data.replace('✅ Trip Verified',' ')

# %%
stopwords=nltk.corpus.stopwords.words('english')
custom_stopwords=['u','pm','am','nd']
stopwords=stopwords+custom_stopwords

# %%
wnl=WordNetLemmatizer()
corpus=[]
for line in sent_tokenize(data):
    temp=re.sub('[^a-zA-z]',' ',line)
    temp=[wnl.lemmatize(word.lower()) for word in temp.split() if word.lower() not in set(stopwords)]
    temp=' '.join(temp)
    corpus.append(temp)

# %%
corpus
# Out:
# ['excellent staff',
#  'hope someone air canada read review',
#  'flew monday th november ac london toronto',
#  'cabin crew friendly supportive looked like love job',
#  'air canada crew like last night beyond good',
#  'although weather condition bad landed delay captain awesome sharing news extra smooth take landing never lost mood kept serving u',
#  'thank much',
#  'worst experience airline',
#  'flew montego bay toronto canada layover',
#  'boarded plane captain advised snowing canada time',
#  'arrived toronto airport spent hour half runway',
#  'due traffic airline plowing',
#  'would think would plowed ahead time least prepped snow',
#  'connecting flight boarding minute lay wait runway',
#  'checked air canada site stated connecting flight delayed hour',
#  'wife believed time make connecting flight sitting hour runway',
#  'well wrong let people connecting flight exit plane first staff website lied delay',
#  'connecting flight time approached gate flight stopped allowed enter u custom closed',
#  'arrived gate time walked foot custom',
#  'knowledge air canada already rebooked flight following day without advising u',
#  'staff rude blamed u custom even told minute',
#  'advised go custom check bag previous flight',
#  'explained send bag later date get home kid',
#  'note people denied well',
#  'also airline sent check bag later date flight running late',
#  'furthermore air canada book hotel room state check',
#  'next day received phone call check',
#  'flight due arrive',
#  'supposed least',
#  'winter clothes coming jamaica clothes due checked bag previous plane',
#  'called several air canada customer service line met excuse',
#  'never fly air canada recommend airline',
#  'warned decided try anyway',
#  'lastly wife checked flight flight leaving toronto next day air canada boomed last flight leaving convenient',
#  'absolutely regard customer',
#  'toronto providenciales',
#  'second time within year shown airport toronto check flight discover ticket booked app get paid',
#  'last time missed flight entirely air canada nothing rectify situation telling issue bank',
#  'ended flying american',
#  'time arrived airport check discover go ticketing purchase ticket',
#  'point either situation receive notification ticket pending payment rather received reference number hour prior flight began receiving check notification',
#  'similar experience last flight',
#  'time booked flight bank phone ensure end',
#  'confirmed',
#  'time due issue inconvenienced stressed able return home family time',
#  'air canada charged baggage offered must issue bank',
#  'unacceptable service poor communication',
#  'thankfully able get flight time',
#  'whitehorse vancouver via toronto air canada turned away airport',
#  'never try fly pet cargo hold',
#  'booking ticket called book cat cargo hold',
#  'moving across country',
#  'everything fine booked pet',
#  'day flight arrived airport turned away due embargo flying pet',
#  'nothing rectify left stranded',
#  'ended fly air north westjet great',
#  'quebec toronto',
#  'seat space seat narrow knee touch front seat',
#  'assign seat h calling airline waiting time min except tant paying extra',
#  'good staff',
#  'london toronto',
#  'found trip air canada b er pretty overwhelming',
#  'enjoyed cabin feel colour',
#  'ife going activated till takeoff meant would wifi ife',
#  'came cockpit pa attention passenger captain speaking',
#  'delayed hour due accident apron',
#  'accident pushback truck broke needed move',
#  'turn ife least one engine',
#  'one hour later pushed back ife came',
#  'decided check entertainment selection',
#  'flight lunch served shortly takeoff',
#  'cheesy pasta sufficient',
#  'meal checked wifi price pretty reasonable',
#  'full flight wifi hour lhr yyz',
#  'later flight served kind pie wrap thing chicken',
#  'brisbane vancouver',
#  'trip sept pleasant comfortable trip',
#  'staff food great',
#  'baggage damaged arrival reported got claim offer immediate repair wheel day however tour elected return home',
#  'within week coming home oct online claim easy enough girl response hr claim settled within week',
#  'cant beat thanks air canada',
#  'montreal tokyo',
#  'welcoming staff montreal airport unbelievably rude',
#  'check machine working one desk open check in',
#  'one desk largest company one important airport canada unbelievable',
#  'minute waiting without improvement people started asking staff happening told minute nothing still line hour come talk problem get',
#  'rest check management staff ground though nice accommodating say',
#  'flight hour tokyo boeing',
#  'plane nice enough cabin crew staff good welcoming',
#  'expecting much food went beyond anything',
#  'chicken white dry blend tomato sauce actually felt sick disgusted eating',
#  'know breakfast supposed could finish',
#  'airline considers best north america really really need improve game',
#  'atlanta toronto embraer',
#  'check staff welcoming basic duty without much enthusiasm',
#  'ticket term stated eligible day standby earlier flight insisted charging change could offer explanation except computer say',
#  'showed ticket said computer tell charge change fee',
#  'despite fact called airline customer service agent phone told show early airport make change free charge',
#  'flight rather uneventful',
#  'plane old seat cramped economy',
#  'crew similarly disinterested unenthusiastic',
#  'end flight chief purser stood door texting phone barely acknowledged passenger disembarking crew outbound flight three day earlier remarkable contrast',
#  'half way flight entertainment system broke',
#  'crew said would reset system could',
#  'sydney vancouver february',
#  'actually want highly commend air canada ticketing agent',
#  'received incredible service gonzalo went way assist purchasing b class economy fare upgrading business using point',
#  'initially could find availability hung disappointed thanking',
#  'gonzalo something air canada agent done called back',
#  'proceeded assist exactly needed',
#  'cannot thank enough',
#  'think receive commendation air canada outstanding beyond helpful service traveller flying air canada',
#  'spend several month traveling summer flew number airline air canada best head shoulder others',
#  'efficient getting people flight crew staff friendly genuinely helpful',
#  'expect food flight',
#  'food good',
#  'stopover program allowed u stopover toronto extra charge',
#  'flight attendant spoke language',
#  'line moved people soon departing flight front line',
#  'example great air canada people',
#  'flight london toronto man taken child london holiday returning home',
#  'child sat together behind u sat aisle seat across',
#  'long flight exhausted dad fell asleep flight attendant took',
#  'mind child delightful flight attendant amazing child',
#  'flight staff made flight pleasant everyone',
#  'daytime flight london toronto october th flight staff really commended',
#  'flight remarkable air canada flight great',
#  'fly air canada every chance get',
#  'sudbury calgary via toronto',
#  'booked ticket sudbury calgary air canada website show available option',
#  'book sudbury toronto toronto calgary separately order get sudbury calgary website automatically',
#  'toronto calgary flight showing h later preferred even though frequently travelled route',
#  'thinking option booked',
#  'checked day departure turn number earlier flight available',
#  'asked change flight result website malfunction air canada employee completely unhelpful refused change flight notwithstanding flight booked time air canada website obviously working properly',
#  'air canada failing many inability book connecting flight air canada website failing show available flight failing help whatsoever',
#  'forced give poor rating',
#  'escalated claim revise rating supervisor end helpful employee took call',
#  'fort mcmurray bathurst via montreal',
#  'paid dollar flight got cancel montreal',
#  'get flight h',
#  'gave dollar eat hotel stay number call discount',
#  'wait line min told room discount call back later',
#  'joke',
#  'london vancouver',
#  'pre boarding board service quite good',
#  'service professional attentive flight',
#  'food could better air canada appear changed menu route year',
#  'ife quite good though ba offer wider choice route',
#  'boeing er air canada high density seating configuration extremely uncomfortable',
#  'seat narrow uncomfortable aisle narrow leg room limited tall',
#  'day time flight aircraft tolerable would avoid possible overnight flight',
#  'toronto vancouver',
#  'fly airline weekly work',
#  'board bigger plane tighter space uncomfortable',
#  'time attendant skipped flight',
#  'ring service ignored',
#  'today luggage left departure',
#  'disappointed',
#  'worst airline ever',
#  'highly unorganized',
#  'never ever going travel one',
#  'rude staff boarding',
#  'traveling montreal toronto give u seat though paid full amount buy ticket',
#  'approached person gate rude listen u',
#  'flight toronto montreal one hr late',
#  'frustrating',
#  'brussels montreal',
#  'improvement last flight',
#  'time food made difference',
#  'vegetarian meal excellent full flavour quality ingredient appropriate size',
#  'red wine board delicious well',
#  'decided abandon air canada international flight took flight',
#  'seems based conversation crew member airport origin matter although hope',
#  'crew kind accommodating nothing could better flight given amount paid portion trip',
#  'ample selection flight entertainment system although judge airline quality based availability wi fi rather treat bonus',
#  'london toronto',
#  'smooth flight landing good food good flight attendant ok clean plane seat comfortable',
#  'toronto munich',
#  'stewardess spoke making sure border collie plane great',
#  'took seat number name got back saying spoke directly gentleman put plane',
#  'although panicked get back right away asked another stewardess quite friendly telling would know dog plane explained could ask captain point asked proof dog gave went ask coming back yes',
#  'montreal seattle',
#  'started making check vest stud spike',
#  'flight delayed ton think issue landing minute boarding started connection',
#  'brought customer service multiple time shrugged dismissed without investigation consideration',
#  'arrived canceled connecting flight transfer luggage forced check time',
#  'scheduled flight literally hour later',
#  'refused asked alternate sent vancouver say hotel arrival',
#  'arrive clue hotel',
#  'dealing another hour get management book room',
#  'get till nearly',
#  'leave wake get ready catch morning connection',
#  'immigration custom line get text saying canceled connection pushed back another flight hour later',
#  'called customer service gave dismissive attitude',
#  'point running hour sleep missed work meeting day',
#  'show sense remorse need remedy',
#  'called demand sort refund said send email',
#  'worth price charge long shot far garbage experience ever airline',
#  'dublin toronto air canada',
#  'hour flight',
#  'boarded took quickly',
#  'really wonderful staff captain',
#  'proud',
#  'multiple announcement keep u know throughout flight',
#  'actually great food',
#  'flying air canada toronto delhi toronto last year premium economy business least year',
#  'service good bad e',
#  'really consistent nothing bad would motivate take time write review',
#  'however time flying direct new delhi toronto oct th ac departure experience worth noting',
#  'settled air hostess came take dinner order choice veg non veg',
#  'coincidentally husband last people got section passenger',
#  'word unfortunately get vegetarian option option left',
#  'got little irritated choice word paid fare every passenger section',
#  'every passenger given choice',
#  'expressed air hostess',
#  'said bring someone else talk come back chat colleague said see meal',
#  'vegetarian would chosen option anyway',
#  'way said quite unprofessional',
#  'span rest hour flight quite unpleasant unprofessional whenever would serving u',
#  'came seat get meal tray back thank smile',
#  'courtesy like basic tenats customer facing industry let alone airline hospitality quite competitive market',
#  'additionally rang call bell entire flight took staff minute multiple time switching grab one attention',
#  'even though walking aisle couple time',
#  'maybe air canada need invest training staff provide best customer service claim advertising',
#  'overall quite disappointing fare price paid',
#  'osaka vancouver',
#  'air host seem frustrated made u feel u favour u board',
#  'going complain seat food yes pay economy expecting luxury',
#  'even making way aisle simple request pleasant exchange',
#  'air conditioning leaking seat tissue stuffed vent prevent',
#  'take stopped notifying cabin crew issue said anything',
#  'ask anything notify tissue shoved vent',
#  'really expect much north american airline',
#  'east middle east much better job class',
#  'idea air canada award',
#  'fly monthly nothing issue airline',
#  'last flight chicago vancouver get text issue entertainment system plane even screen flight hour',
#  'flight home edmonton given seat one headphone jack worked',
#  'disappointed',
#  'toronto london',
#  'review check desk staff',
#  'kid parent travelling seat together',
#  'staff humble helpful went beyond get seat together',
#  'really appreciate effort kid month old',
#  'really thankful lady',
#  'past thursday way back vancouver dc montreal air canada',
#  'second leg trip seated th row preferred seating front exit row discovered seat recline',
#  'asked flight director could move take remembered request moved u two vacant bulkhead seat',
#  'rest flight crew professional attentive',
#  'felt important acknowledge crew went beyond make trip enjoyable',
#  'toronto new delhi',
#  'waited purchase duty free told impossible le hour left flight',
#  'originally pushed service button hour prior duty free closing one crew member came assistance',
#  'went flagged crew member explaining fact waiting hour someone bring duty free',
#  'left said would return min',
#  'min later came back notifying flight passed hour marker unable provide duty free',
#  'fault yet crew member entertaining service call realized bad air canada canadian disappointed service offer',
#  'never using air canada',
#  'would rather fly airline care traveller',
#  'dubai toronto',
#  'travelling kid husband',
#  'daughter got bug bite',
#  'common get',
#  'itchy cry',
#  'lady behind u told flight attendant hurt',
#  'flight attendant called nurse board one nurse came assisted',
#  'everything okay',
#  'get medication slept good',
#  'reaching toronto airport asked flight attendant procedure bug bite',
#  'said give address one everything',
#  'went gate boarding regina said allowed travel get approval med assistant',
#  'send u customer service',
#  'hard u travel kid walk way customer service',
#  'tired day travel',
#  'get good experience person customer service',
#  'missed flight regina',
#  'called med assistant',
#  'med assistant said daughter consulted call doctor air canada',
#  'otherwise take kid clinic fill page form',
#  'without sent u winnipeg',
#  'bad experience travel',
#  'montreal dubai via toronto',
#  'would like express disappointment air canada customer service',
#  'flight delay montreal causing miss flight toronto dubai',
#  'customer service failed book alternative flight responding communication email one answering calling phone',
#  'montreal passenger promised booking direct flight toronto dubai',
#  'reached toronto airport surprised booked u british airway via london consideration class booking visa restriction might clearly explained staff montreal',
#  'option emirate',
#  'air canada staff book u emirate excuse seat available',
#  'booked emirate since sending email refund express disappointment response care need customer',
#  'really recommend air canada got stuck customer service never receive good service neither help',
#  'serious delay canadian border tried call customer service inform might late check',
#  'hold minute twice',
#  'operator consultant available',
#  'arrived airport minute gate closed informed client manager checkin line',
#  'told wait turn',
#  'obviously missed flight',
#  'ticketing office offered ticket x original price',
#  'luggage refund apply online could take week',
#  'customer service ticketing counter callous interested client',
#  'line another minute',
#  'consumer vote wallet',
#  'air canada never pleasure clientele ever',
#  'toronto vancouver',
#  'airline getting ridiculous day',
#  'keep eliminating staff replacing machine',
#  'remaining staff getting useless',
#  'started charging one single luggage unless pay high fare',
#  'want check small carry bag charge',
#  'limited food option domestic north american flight outrageous low quality food international route hardly digestible',
#  'world airline competing get worse air canada one top contender',
#  'vancouver yellowknife',
#  'flight fine flight crew nice customer service phone horrible',
#  'bag got lost way yellowknife',
#  'work tv show speciality clothing thing need go work cannot tell bag',
#  'call centre seems like another country idea talking',
#  'disappointed customer service still received bag',
#  'brisbane vancouver',
#  'moment greeted cabin crew knew good flight',
#  'pleasantly surprised leg room general space aircraft',
#  'food option suitable journey cabin well lit reduce jet lag',
#  'punta cana toronto',
#  'air canada get worse worse minute',
#  'company shut',
#  'always issue sort',
#  'son arrived yyz',
#  'almost still waiting outside',
#  'mention received another update saying would another minute',
#  'absolute disgrace',
#  'always garbage',
#  'toronto vancouver',
#  'flight left time cabin crew extremely friendly attentive',
#  'two serving tea coffee etc one water plus meal service',
#  'tried bistro menu first time great fine hungry price reasonable',
#  'greeted attendant captain upon leaving aircraft',
#  'enjoyable experience round',
#  'los angeles vancouver',
#  'employee work air canada counter lax name gloria accommodating lovely arrived',
#  'made check smooth easy',
#  'la guardia toronto',
#  'day started journey toronto pearson airport flight late one half hour today returning canada airline flight time reaching laguardia airport suddenly change flight departure time',
#  'one hour changed departure time',
#  'really frustrating boring',
#  'seems service airline bad',
#  'need pick car park n fly zone',
#  'doubt going lose money due delay',
#  'question take responsibility financial loss stress going hurt health',
#  'san francisco toronto',
#  'got flight staff check counter extremely rude forced u check legally sized carry bag',
#  'part boarding group claimed overhead storage already full',
#  'boarding plane realized storage compartment nearly wide open',
#  'remaining group continued bring carry bag much larger main cabin overhead',
#  'flight attendant appalled checking agent forced u check bag everything could get bag main cabin competent person encountered deserves raise',
#  'fact checking agent decided single u absolutely ridiculous inexcusable',
#  'air canada every opportunity make boarding experience pleasant fair absolutely excuse kind incompetence',
#  'vancouver paris',
#  'poor experience air canada',
#  'hard seat space optimization gone far',
#  'bad food vegan like pasta taste awful salad cheap chocolate muffin',
#  'worst entertainment system must watch minute ad choice film musique game access music compilation possibility selecting precise artiste soundtrack',
#  'company service level similar low cost',
#  'vancouver melbourne',
#  'flight largest flight trip second last flight flight trip first time air canada',
#  'pleasantly surprised friendliness staff chatty wanted know time canada thought nice considering flying economy class',
#  'seat comfy compared lufthansa flight entertainment much better lufthansa',
#  'overall flight went quick great service food entertainment comfort',
#  'recommend air canada long haul flight canada stick singapore airline rest world reward system amazing',
#  'great flight air canada',
#  'vancouver osaka',
#  'check boarding fine ac',
#  'seat quite uncomfortable seemed smaller remember',
#  'meal pathetic served plastic container virtually tasteless',
#  'choice pasta chicken rice',
#  'struggle tear sealed lid',
#  'drink meal',
#  'plastic bottle wine beer offer meal one permitted',
#  'disappointed looking forward flight',
#  'flown ac internationally long time live bangkok usually fly cx',
#  'remember ac international inflight service pretty good',
#  'happened',
#  'toronto philadelphia',
#  'flew business class via air canada',
#  'due unknown delay mentioned flight prior landing determined bag would make transfer gate landed flight departure depart',
#  'minute based scheduled departure time minute actual time',
#  'able get gate time ran sure',
#  'arrived gate f still boarding zone',
#  'upon attempting board informed moved',
#  'gate agent rude offered exactly consolation new ticket scheduled leave hour later',
#  'immediate prior time flying air canada also malpensa delayed hour causing u miss lake como part milan trip',
#  'book air canada',
#  'today experience air canada frustrating',
#  'got catch flight ottawa',
#  'flight cancelled due mechanical failure',
#  'directed another flight reassured destination departure arrival luggage would follow shortly',
#  'two hour past arrival luggage told arrive hotel midnight',
#  '',
#  'exhausted important meeting tomorrow',
#  'good',
#  'air canada canceled boston montreal flight good reason missed montreal connection lyon ended moving business class coach tap airline lisbon',
#  'barely made lyon first woman world cup going watch two grandchild return asked refund change class difference fare',
#  'offered',
#  'still fighting',
#  'second time flying air canada',
#  'first last august boston kelowna via toronto',
#  'due delayed flight missed connection air canada offered courtesy sleep floor toronto delayed hour overnight',
#  'time flight delayed kelowna calgary missed connection calgary london',
#  'air canada offered nothing rebook next flight',
#  'lost whole day uk',
#  'okay',
#  'lady airport lovely outcome still insanely disappointing',
#  'forget feeling basically suck pay upgrade get time terrible',
#  'never flying trip',
#  'calgary tokyo',
#  'special meal prebooked given cold',
#  'pasta dish still cold quinoa salad side frozen',
#  'kindly mentioning one flight attendant told nothing could frozen salad could heat pasta meal bit',
#  'apology effort get another salad frozen',
#  'despite reheating meal still slightly cold returned',
#  'nobody went beyond make poorly served meal',
#  'making sure avoid booking air canada future',
#  'vancouver calgary',
#  'called air canada needed change flight',
#  'ran many problem calling asked change flight different day said possible asked cancel outbound flight keep inbound flight',
#  'said could done',
#  'asked representative told',
#  'trying check inbound flight would allow saying forfeited flight',
#  'gave huge run around trying figure happening',
#  'toronto hong kong premium economy first time',
#  'although significantly expensive economy also significantly better',
#  'across economy painful',
#  'reason writing review would give air canada top mark experience one particular person gave daughter',
#  'running aisle multiple time middle hour flight got attention one flight attendant joyce',
#  'getting ok spent next hour showing daughter whole back plane service worked gave daughter experience never forget',
#  'amazing air canada lucky',
#  'booked airline ticket april air canada vancouver canada cancun mexico regular airline',
#  'received notice august flight back changed air canada rouge new flight number different aircraft changed time departure',
#  'phoned air canada asked speak supervisor requested seated preferred seating addition cost compensation downgraded refused request',
#  'try dec new air passenger regulation come effect',
#  'hope new regulation put end air canada rescheduling flight regular aircraft low cost carrier rouge without compensation air canada client',
#  'seat comfort terrible rouge',
#  'toronto ottawa',
#  'flew different airline dublin toronto missed air canada flight took hour get immigration control went air canada desk ask',
#  'man serving seem know flight night full fine told rebooked onto one next morning print boarding pas sent call help line phone airport',
#  'half hour trying get went speak someone else print boarding pas thankfully rebooking charge previously told missing flight fault',
#  'next flight following morning delayed',
#  'traveling beijing philadelphia making transfer toronto',
#  'air canada cancelled connecting flight last minute',
#  'since traveled month old infant asked airline staff please help u book next available flight one willing help',
#  'staff airport indifferent',
#  'overall experience air canada toronto airport terrible',
#  'frequent traveler ac last year k experience flying ac getting worse worse',
#  'seat leg room getting smaller fleet aging airline consistent staffing issue',
#  'sure staffing issue related number people staff causing burnout rank poor training customer definitely felt',
#  'experience besides order boarding access lounge altitude status irrelevant',
#  'flying air canada calgary boston toronto last five year',
#  'year boston toronto leg least three hour late leading due broken connection',
#  'never time',
#  'avoid',
#  'flying delta minneapolis salt lake next year',
#  'family young child one freshly broken arm flying flight london toronto vancouver terrace bc',
#  'upon arriving airport discovered supposedly free checked bag free',
#  'got td aeroplan card told primary card holder get free checked bag husband got',
#  'one told u got free booked aeroplan point time enough point yet',
#  'air canada attendant told u information friendly polite stayed super friendly lady whole way',
#  'lady went got sheet pointed detail',
#  'choice pay bag',
#  'known advance would left lot stuff parent home took fit carry',
#  'would brought stuff later flying home west jet get free checked bag everyone else flying matter pay flight',
#  'paying someone told authority waive bag fee wanted',
#  'experience want fly air canada',
#  'last flight vancouver terrace delayed attendant amazing full smile super friendly even stress trying get plane ready people waiting long time',
#  'great personality great kid board',
#  'last flight might decided fly air canada point book future flight westjet get free st checked bag anyone flying matter pay flight',
#  'also never issue service westjet',
#  'used work customer service giving super great happy customer service big thing expect spending money service product',
#  'would given rating last flight super great attendant wont give rating',
#  'london toronto much better experience air canada one enjoyed last monday tuesday although flight back london th august ok bad part flight sat back plane worst place sit plane engine loud felt big turbulence',
#  'flight toronto st july much better great part flight originally supposed sit h aisle seat changed k window seat best seat engine much quieter return flight',
#  'mex yul flight operated air canada rouge',
#  'check boarding gate staff mex fantastic polite courteous efficient',
#  'legroom insufficient tall knee touching seat front',
#  'personal entertainment screen need download app',
#  'food sold plane mediocre bring snack',
#  'crew actually nice helpful',
#  'yul yyz bog check online kiosk forced go counter',
#  'long check line agent attending general line',
#  'since travelled alone small child quite lot baggage attempted use special assistance line',
#  'immediately confronted rude agent barked standing right place',
#  'move meter family check rude arrogant way sent check entrance',
#  'attended another agent rude arrogant',
#  'apparently flight cancelled stay hr',
#  'montreal',
#  'apology explanation rude condescending attitude',
#  'effort accommodate another flight',
#  'next day could use kiosk use check counter',
#  'ground staff yul rude slow inefficient agent attending family taking passenger general line',
#  'flight yyz bog crew nice friendly airplane old dirty worn seat inflight entertainment',
#  'altogether would spend money elsewhere',
#  'seoul toronto',
#  'photogenic uncomfortable',
#  'air canada business class probably worst herringbone configuration design',
#  'seat extremely hard space bed table limited almost impossible turn without hitting table knee sleeping position',
#  'ac provide pajama amenity kit cheap',
#  'used airline return flight toronto havana montreal',
#  'even hour flight airline serve food alcoholic drink',
#  'seat narrow much legroom',
#  'also web checkin site rd august work hour prior flight',
#  'called customer service twice wait almost hour someone took call telling could help',
#  'worst toronto august rd flight delayed hr',
#  'air canada inform infact web page still showed original time time',
#  'service called tripcase informed delay',
#  'airport check machine nit work either',
#  'many year ago used reputable airline',
#  'longer seems',
#  'choice fortunately',
#  'madrid toronto',
#  'bag delayed day staff air canada careless',
#  'without clothes day careless',
#  'flew madrid toronto th august',
#  'leave asked air canada bag told wont flight arrive tomorrow',
#  'arrived toronto informed air canada registered system told delivered hour',
#  'arrive',
#  'day without bag',
#  'purchased one layover trip air canada delhi india round trip route dc toronto delhi delhi toronto dc',
#  'however day departure day received email letting know flight schedule changed',
#  'speaking representative informed air canada terminated toronto delhi route would placed different flight order reach destination date initially selected',
#  'back forth able placed two layover journey india following route dc montreal munich delhi delhi vancouver toronto dc',
#  'result change initial one layover h trip turned two layover h voyage',
#  'additionally booking trip asked select pay seat seat free charge',
#  'boarded realized assigned seat purchased',
#  'contacted air canada never received reply',
#  'august one day return flight received text message air canada letting know ac return flight would departing although return flight initially placed scheduled leave',
#  'course return boarding gate two three flight changed shortly boarding resulting delay one flight',
#  'london toronto via halifax',
#  'definitely old ac business class',
#  'drink order take champagne offered mimosa maybe time day',
#  'meal delivered automaton crew couple stood warmth say london kitchen came vegan delicious chick pea curry mushroom steamed spinach baked tomato',
#  'toronto ac kitchen take note mostly appalling idea vegan food served',
#  'croissant know vegan worth stray',
#  'meal service crew scarce',
#  'minute take drink crew member seen',
#  'press call button couple hour order red wine top meal',
#  'still best business class seat north america though entertainment pretty mediocre compared year ago managed find something hbo keep hooked whole flight',
#  'london toronto',
#  'hour delay unexplained scheduling issue delayed flight lhr',
#  'complete mess boarding process meant whole thing turned melee',
#  'policy carry bag meant wasted minute trying find space everyone hand luggage',
#  'also old plane fully cleaned',
#  'flew montreal dublin one new',
#  'brand new paint job outside inside left lot desired',
#  'faulty recline old seat wonky tray table dated tatty cabin',
#  'entertainment screen failed started crew idea',
#  'big deal thing happen crew handed coupon',
#  'week later return flight plane gate attendant tell u entertainment system still working',
#  'playing air canada',
#  'sending defective aircraft transatlantic flight really week fix',
#  'rating cabin crew good',
#  'looking forward aer lingus route next year',
#  'purchased air canada ticket higher price order get shorter connection time',
#  'instead got delayed hr milan toronto hr toronto montreal',
#  'asked customer service could make earlier flight toronto montreal told hr sufficient time transfer baggage',
#  'look like hr min enough baggage transfer paid initial itinerary least thats presented',
#  'toronto shanghai',
#  'seat comfort terrible',
#  'air canada used average airline aircraft configuration passenger comfort least thought',
#  'seat tight washroom long line ultra long flight like mine',
#  'flight toronto montreal montreal toronto delayed',
#  'first toronto montreal captain late crew late',
#  'waited h plane without moving',
#  'coming back montreal toronto delayed hour waiting plane',
#  'captain make announcement apologizing delay still waiting passenger supposed plane',
#  'guess next time sleep air canada park plane wait',
#  'never flew aircanada issue would definitely suggest staying away possible',
#  'book another airline save pain',
#  'toronto london',
#  'boeing ok aircraft',
#  'premium economy bigger seat',
#  'onboard staff know smile',
#  'small glass orange juice water premium econ compared virgin get prosecco',
#  'food really odd',
#  'breakfast omelette fried potato creme freche hr flight toronto lhr',
#  'followed turkey cheese rol',
#  'vegetarian option without booking ahead breakfast followed snack hr flight',
#  'lunch',
#  'like bus costing nearly k seat',
#  'toronto rome',
#  'excellent check process dedicated area oversize luggage handled efficiently',
#  'maple leaf lounge lacked european newspaper tired',
#  'efficient boarding process welcome drink attention prior take purser told late arriving commissary struggling board passenger hence service business class prior take',
#  'comfortable lie flat seat good selection wine champagne',
#  'dinner acceptable poorly presented',
#  'excellent breakfast freshly cooked omelette',
#  'service courteous efficient lacked charm really seemed cabin crew going motion',
#  'time departure arrival',
#  'continue fly air canada business class flight one best experienced',
#  'la guardia dublin via toronto',
#  'checked flight already knew would miss connection asked make sure lose bag flight delayed due weather',
#  'reached gate asked agent check connection said came late flight final destination next two day',
#  'delayed missed connection many airline none disorganized',
#  'first leg flight new york toronto',
#  'toronto bag already lost',
#  'reached lady file claim told bag lost rather told return next day find next day returned find hour next flight still find time bag make connection',
#  'told file claim reached final destination ac dismissive final destination izmir turkey allow file claim',
#  'tried file claim online needed incident report number since one ever filed claim never received incident number',
#  'phone unhelpful rude',
#  'first wait minute even get agent told file lost found item',
#  'trying understand get bag back',
#  'toronto san francisco',
#  'worst flight',
#  'long overlay toronto flight changed',
#  'put earlier flight put middle seat',
#  'never',
#  'flew air canada yvr nrt back yvr flight pretty good',
#  'seatback pocket average',
#  'price pretty good',
#  'boarding zone assigned like line nice',
#  'seat comfortable would prefer leather seat cushioning',
#  'staff friendly spoke multiple language',
#  'ife ok selection',
#  'food good time',
#  'recline average',
#  'toronto philadelphia flight never happened bad weather',
#  'flew calgary connected toronto pearson philadelphia',
#  'changed gate twice announced flight cancelled without giving u instruction going happen next',
#  'asked sent u air canada info desk representative stated nothing moment bc flight going philadelphia bad weather',
#  'took u private hallway handed u refund info card',
#  'told u baggage claim',
#  'baggage took hour get',
#  'automatically booked u next afternoon flight',
#  'canceled rebooked two day later flight',
#  'nobody contact u help',
#  'left stranded find mean get toronto',
#  'work loss',
#  'time wasted phone',
#  'air canada handled situation poorly irresponsible',
#  'weather philadelphia bad telling u',
#  'friend family philadelphia confused bc weather fine',
#  'never going fly air canada',
#  'frustrated sicking sitting megabus nyc philadelphia',
#  'toronto montreal',
#  'problem system lack sufficient staff deal backlog',
#  'pre paid luggage able check staff unhelpful',
#  'rome toronto',
#  'seat comfortable seat belt really sticky',
#  'service friendly entertainment fully functional',
#  'regarding passenger flight group slob used bathroom halfway flight cup filled paper towel toilet flushed etc',
#  'blame air canada passenger slob',
#  'prague toronto supposed continue flight washington dc',
#  'carry luggage took board',
#  'trying find place store luggage one steward told take care',
#  'really nice',
#  'asked important stuff took document school left luggage',
#  'learned suitcase checked rest checked suitcase gave luggage number',
#  'told going way dc told idea suitcase going way dc ask employee airport happen suitcase',
#  'idea suitcase checked plane storage',
#  'nothing could afterwards',
#  'got plane toronto asked five people every single one told different information',
#  'nevertheless later told lost suitcase find',
#  'nobody able give proper information',
#  'hearing know people actually trying help really frustrating supposed catch connecting flight obviously catch',
#  'finally found suitcase told join next flight dc',
#  'since carry suitcase checked wait hour toronto flight delayed minute',
#  'instead getting dc arrived midnight',
#  'rome toronto',
#  'excellent flight',
#  'welcoming refreshment boarding good choice newspaper',
#  'professional courteous competent flight staff',
#  'excellent meal better coming toronto',
#  'good choice wine champagne',
#  'flight entertainment easy operate good selection film etc',
#  'expect air canada',
#  'time departure arrival',
#  'bag promptly delivered',
#  'london toronto flight delayed first bathroom sink working causing u miss time slot departure eventually made u miss connection',
#  'awful experience air canada recent trip europe',
#  'every single flight trip delayed least worry',
#  'way bag lost',
#  'unable contact anyone could give information',
#  'received nearly day later severely damaged',
#  'way home even trouble',
#  'due substantial delay missed connecting flight montreal stay extra day could get another flight home',
#  'denied compensation hotel room cab fare food stuck unexpectedly montreal extra day',
#  'gave phone number call get hotel room discounted rate',
#  'however finally got told discounted rate left best could offer room marriott',
#  'thanks',
#  'booked hotel room half price expedia instead',
#  'finally got home next day think bag made home',
#  'course',
#  'delayed damaged',
#  'also denied claim refund baggage fee guess paid way privilege bag lost destroyed',
#  'impossible get ahold actual person talk nightmare trip online claim denied',
#  'received compensation even though spent hundred extra dollar result air canada incompetence',
#  'friend also flying air canada different flight attend wedding similar trouble well',
#  'isolated incident',
#  'air canada joke treat customer terribly',
#  'never recommend anyone',
#  'montreal toronto',
#  'first cancelled initial flight ac supposedly operational reason rebooked passenger flight created nowhere departing hour later ac',
#  'new flight hour late',
#  'finally arriving toronto bag sent later flight',
#  'sorry guy',
#  'london heathrow toronto',
#  'awesome flight air canada checked seat originally h lady airport changed seat k window seat sat next wing',
#  'boarded went meet pilot gentleman',
#  'also long time took flight',
#  'always go engine seat',
#  'toronto laguardia',
#  'flight cancelled due thunderstorm completely air canada control',
#  'however way dealt situation terrible',
#  'zero customer service',
#  'sitting hot plane hour',
#  'flight cancelled told go level desk',
#  'wait min line nothing',
#  'told go desk told go desk',
#  'hour additional inconvenience',
#  'hotel voucher refund stranded toronto night',
#  'air canada high flight cancel rate system place situation',
#  'also flight toronto know plane',
#  'calling passenger name intercom plane take confirm fact board',
#  'people plane aware unacceptable',
#  'connection flight victoria vancouver rescheduled delayed three time would miss connecting air canada flight sfo',
#  'landed min run gate',
#  'go thru custom',
#  'missed flight',
#  'bumped u flight',
#  'earlier flight asked standby',
#  'others flight made onboard earlier flight',
#  'never called boarding pas',
#  'went gate counter several time',
#  'seat flight hour earlier said would problem getting lot seat',
#  'loaded everyone seat category would give u including paying upgrade first class',
#  'said time get u boarding pas',
#  'offered food coupon per person',
#  'due scheduling issue behalf air canada frequent flyer time said late happens time',
#  'supervisor would give u refund could fly another airline get home',
#  'wait airport total hour repeated scheduling error',
#  'brussels calgary via montreal',
#  'first flight brussels montreal screen seat broken nothing crew could',
#  'airplane old well',
#  'second flight boarded hr late screen didnt work',
#  'waiting min plane departure broken airconditioning exit plane wait hour another plane finally able depart',
#  'would recommend',
#  'booked paid higher price direct flight taking hour departing early afternoon heathrow st john newfoundland',
#  'air canada later cancelled flight appropriate reason rescheduled u onto indirect flight via toronto taking hour requiring departure home young child failed provide meaningful compensation',
#  'e mail customer service way contact resulted rude unprofessional response',
#  'want complain compensation also attitude customer service',
#  'however seem publish complaint procedure anywhere',
#  'therefore nearly week ago e mailed ask complaint procedure unhappy response customer service responded',
#  'thought air canada would professional well run business competent trained efficient staff',
#  'experience nothing could truth',
#  'toronto vancouver',
#  'excellent flight air canada last week',
#  'lr pod ac signature service wonderful',
#  'staff attentive friendly',
#  'beef salad dessert cheese glass wine memorable',
#  'flew latitude fare full fare economy gave grade economy seat front cabin',
#  'advice fly several time year fly carrier alliance notice treat like gold',
#  'one look lower cost fare',
#  'however tall guy really appreciate service big seat comfy',
#  'also ife excellent',
#  'ac wide body plane excellent number choice front cabin large screen',
#  'watched two film hopefully fly ac watch half third film watching',
#  'appreciate classic film recent film necessarily first choice',
#  'toronto pearson london heathrow',
#  'airline amazing',
#  'er old',
#  'staff lovely flight time',
#  'toronto pearson london heathrow best hour airline',
#  'would recommend airline',
#  'one best airline money buy',
#  'food shabby well',
#  'arrived london heathrow baggage reclaim excellent',
#  'mix problem',
#  'star',
#  'connection flight victoria london stopped vancouver h min stop arranged airline air canada website experienced flyer able would booked h flight rather h flight ended',
#  'first flight victoria delayed half hour mean even le time get flight knew vancouver airport rather large',
#  'flight delayed meaning even though supposed take actually took min next flight supposed take',
#  'people flight u also told going try get vancouver hold flight u already many delay vancouver',
#  'however flight held u fact take earlier supposed',
#  'missed flight expected compensation meant entire journey delayed full day flight could get u evening air canada even provide hotel u despite cause h delay',
#  'well paid money put preferred seating extra legroom brought booking u next flight unable anything help u',
#  'understand people would booked seat would unable change even several conversation customer service airline asking could possibly upgrade u premium economy paid room getting delayed incompetence remained unhelpful throughout whole process',
#  'overall although individual employee trying best help u airline whole awful helping u made journey difficult fact selling u ticket hour lead problem face',
#  'toronto montreal',
#  'k status airport since still way home montreal',
#  'flight leave toilet flushing pilot tell u go airport',
#  'staff gate let u go',
#  'chicago montreal',
#  'flight amazing',
#  'problem long hour delay due poor weather chicago',
#  'boarded everything clean',
#  'met amazing flight attendant sadly forgot name',
#  'sat noticed ife screen regional jet',
#  'problem bit unresponsive',
#  'got air drink service wanted could purchased voucher buy board menu could bought menu',
#  'card',
#  'limited selection due oven embraer aircraft opted chicken noodle soup',
#  'sadly run oatmeal instead',
#  'smooth flight',
#  'bag carousel got gone',
#  'montreal vancouver',
#  'lighting storm stopped flight day public holiday jazz festival sunday helped meant could put motel',
#  'problem communication tired stressed traveller',
#  'able organise security subdue traveller official announcement communication priority',
#  'came hour late baggage delivered hour nobody could really leave anyhow',
#  'cabin staff short rude eventual flight anyhow many sleeping airport hour',
#  'montreal grenada',
#  'connecting flight toronto however plane technical issue montreal consequence missed connecting flight',
#  'lost day sandal resort complicated sort refund air canada many document requirement complex process hard reach',
#  'montreal paris',
#  'hr flight delay apologize boarding gate',
#  'plane old uncomfortable ife remote control located armrest seat',
#  'catering worst',
#  'flew dubai montreal montreal porto air canada rouge',
#  'air canada lost luggage flight way tell would delivered',
#  'fly regularly business time year luggage lost last five year',
#  'always seem problem ac last time flew cancelled flight stuck toronto',
#  'canada deserves better',
#  'ok getting senile',
#  'back vowed would never fly air canada stupidly year decided use short sector',
#  'received shortly left airport text message telling forget flight halifax went airport',
#  'went check woman handling desk going use could say anything next door colleague announced loud voice flight cancelled',
#  'aircraft come halifax hour away someone told computer send message telling',
#  'air canada customer handling came fore come back get flight',
#  'explained connection day',
#  'whilst one two check staff made effort sort problem indicated could care le problem',
#  'due pay full fare westjet wife self',
#  'said contrast could greater check lady spoke bent backwards help u thank westjet',
#  'told wife even think air canada certified',
#  'flight montreal vienna delayed going leaving following morning',
#  'caused miss bus vienna munich cost euro',
#  'spent hour airport waiting',
#  'anything give coupon use air canada',
#  'never going use never want fly air canada',
#  'way home vienna flight delayed hour half causing miss another ride get hotel night vancouver live hour drive airport',
#  'well done ac',
#  'barcelona vancouver via montreal',
#  'dad supposed home yesterday flight cancelled spend night airport',
#  'phone line long hold minute could actually get',
#  'waiting hour half hold mom disconnected',
#  'rather teaching staff deal tired frustrated people waiting simply sent armed security guard threatened arrest anyone rude air canada staff',
#  'want dad home',
#  'still waiting',
#  'rome toronto',
#  'flight delay hour miss connecting flight milwaukee',
#  'landed rush check next connecting flight approach ground staff given next day flight staff said cannot anything direct counter f check optional flight chicagon',
#  'choice take option fly next day',
#  'immigration realise left laptop magazine compartment',
#  'go lost found cannot locate lost found staff send message twice check flight still sign']

# %%
data=[]
# iterate through each sentence in the file 
for i in corpus: 
    temp = [] 
      
    # tokenize the sentence into words 
    for j in word_tokenize(i): 
        temp.append(j.lower()) 
  
    data.append(temp) 
    # Create CBOW model :
model1 = gensim.models.Word2Vec(data, min_count = 1,  
                              size = 100, window = 5) 
  
# Print results 
print("Euclidian similarity :: CBOW : ", 
    model1.similarity('bad', 'airline'))
# Out:
# Euclidian similarity :: CBOW :  0.10869773

# %%
model1.most_similar('airline')
# Out:
# [('canada', 0.49154600501060486),
#  ('boarding', 0.4739355742931366),
#  ('staff', 0.471762478351593),
#  ('air', 0.45404672622680664),
#  ('left', 0.4434630274772644),
#  ('service', 0.4406808018684387),
#  ('flight', 0.43097391724586487),
#  ('claim', 0.4259015619754791),
#  ('toronto', 0.4193202555179596),
#  ('connection', 0.3957015872001648)]
